# %% [markdown]
# 1. Clean data

# %%
import re

def clean_wikipedia_text(text):
    # Remove citations like [1], [2][3], [citation needed]
    text = re.sub(r'\[[^\]]+\]', '', text)
    
    # Remove URLs
    text = re.sub(r'http[s]?://\S+', '', text)
    
    # Remove parenthetical information
    text = re.sub(r'\([^)]*\)', '', text)
    
    # Remove special formatting (e.g., ''italic'' or '''bold''')
    text = re.sub(r"''+|\<.*?\>", '', text)
    
    # Remove extra whitespace
    text = re.sub(r'\s+', ' ', text).strip()
    
    # Remove lines starting with special characters (-, *, digits)
    text = '\n'.join(line for line in text.split('\n') if not line.strip().startswith(('-', '*', '1.')))
    
    return text

# Load text and clean
with open('data/wiki_dataset.txt', 'r', encoding='utf-8') as file:
    raw_text = file.read()

cleaned_text = clean_wikipedia_text(raw_text)

# Save cleaned text
with open('data/cleaned_wiki_text.txt', 'w', encoding='utf-8') as file:
    file.write(cleaned_text)

# %% [markdown]
# 2. Spit data into 3 subset for training, testing and validation

# %%
import random
import re

# Load and preprocess corpus
with open('data/cleaned_wiki_text.txt', 'r') as file:
    # Convert to lowercase
    corpus = file.read().lower()

# Clean up text: remove extra newlines and leading/trailing spaces
corpus = re.sub(r'\n+', ' ', corpus).strip()  # Replace multiple newlines with a space
corpus = re.sub(r'\s+', ' ', corpus) 
 # Replace multiple spaces with a single space

# Split into sentences
sentences = corpus.split('.')

# Remove empty sentences
sentences = [sentence.strip() for sentence in sentences if sentence.strip()]

# Shuffle sentences
random.shuffle(sentences)

# Split into training, validation, and testing sets
train_split = int(0.7 * len(sentences))
val_split = int(0.8 * len(sentences))

train_set = sentences[:train_split]
val_set = sentences[train_split:val_split]
test_set = sentences[val_split:]

# Verify results
print(f"Total sentences: {len(sentences)}")
print(f"Training set: {len(train_set)} sentences")
print(f"Validation set: {len(val_set)} sentences")
print(f"Testing set: {len(test_set)} sentences")

# Optional: Save the sets to files for further use
with open('data/wiki_article/train_set.txt', 'w') as file:
    file.write('. '.join(train_set) + '.')

with open('data/wiki_article/val_set.txt', 'w') as file:
    file.write('. '.join(val_set) + '.')

with open('data/wiki_article/test_set.txt', 'w') as file:
    file.write('. '.join(test_set) + '.')
# Out:
# Total sentences: 589
# Training set: 412 sentences
# Validation set: 59 sentences
# Testing set: 118 sentences

# %%
import re
from nltk.tokenize import word_tokenize
from collections import Counter

# Tokenize
tokens = word_tokenize(' '.join(train_set))
vocab_size = 20000 # Limit vocabulary size
token_counts = Counter(tokens)
vocab = {word for word, _ in token_counts.most_common(vocab_size)}

# Clean up unwanted characters
def clean_tokens(tokens):
    cleaned = []
    for sentence in tokens:
        cleaned_sentence = [re.sub(r'[^\w.]', '', word) for word in sentence]  # Keep only words and periods
        cleaned_sentence = [word for word in cleaned_sentence if word]  # Remove empty tokens
        cleaned.append(cleaned_sentence)
    return cleaned

# Replace words not in vocab with <UNK> and clean
def replace_with_unk(data):
    return [
        [word if word in vocab else '<UNK>' for word in word_tokenize(sentence)]
        for sentence in data
    ]

train_tokens = replace_with_unk(train_set)
val_tokens = replace_with_unk(val_set)
test_tokens = replace_with_unk(test_set)

# Clean the tokenized data
train_tokens = clean_tokens(train_tokens)
val_tokens = clean_tokens(val_tokens)
test_tokens = clean_tokens(test_tokens)

# Check results
print(train_tokens[:10])  # Show first 10 sentences from train_tokens
print(val_tokens[:10])    # Show first 10 sentences from val_tokens
print(test_tokens[:10])   # Show first 10 sentences from test_tokens
# Out:
# [['despite', 'adopting', 'an', 'anticorruption', 'law', 'in', '2010', 'corruption', 'prevails', 'throughout', 'the', 'country'], ['some', 'critics', 'of', 'the', 'government', 'have', 'been', 'arrested', 'for', 'allegedly', 'spreading', 'fake', 'news', 'about', 'the', 'covid19', 'pandemic', 'in', 'cambodia'], ['hinduism', 'has', 'left', 'little', 'trace', 'beyond', 'the', 'magical', 'practices', 'of', 'tantricism', 'and', 'a', 'host', 'of', 'hindu', 'gods', 'now', 'assimilated', 'into', 'the', 'spirit', 'world'], ['there', 'is', 'also', 'a', 'frenchlanguage', 'newspaper', 'and', 'some', 'tv', 'channels', 'are', 'available', 'in', 'french'], ['after', 'the', '2013', 'cambodian', 'general', 'election', 'allegations', 'of', 'voter', 'fraud', 'from', 'opposition', 'party', 'cambodia', 'national', 'rescue', 'party', 'led', 'to', 'widespread', 'antigovernment', 'protests', 'that', 'continued', 'into', 'the', 'following', 'year'], ['the', 'credit', 'bureau', 'further', 'increases', 'the', 'transparency', 'and', 'stability', 'within', 'the', 'cambodian', 'banking', 'sector', 'as', 'all', 'banks', 'and', 'microfinance', 'companies', 'are', 'now', 'required', 'by', 'law', 'to', 'report', 'accurate', 'facts', 'and', 'figures', 'relating', 'to', 'loan', 'performance', 'in', 'the', 'country'], ['in', '2010', 'the', 'royal', 'cambodian', 'armed', 'forces', 'comprised', 'about', '102000', 'active', 'personnel'], ['other', 'key', 'habitats', 'include', 'the', 'evergreen', 'and', 'dry', 'dipterocarp', 'forests', 'of', 'mondolkiri', 'province', 'protected', 'by', 'keo', 'seima', 'wildlife', 'sanctuary', 'phnom', 'prich', 'wildlife', 'sanctuary', 'and', 'srepok', 'wildlife', 'sanctuary', 'as', 'well', 'as', 'ratanakiri', 'province', 'and', 'the', 'cardamom', 'mountains', 'ecosystem', 'including', 'preah', 'monivong', 'national', 'park', 'botumsakor', 'national', 'park', 'and', 'the', 'phnom', 'aural', 'wildlife', 'sanctuary', 'and', 'phnom', 'samkos', 'wildlife', 'sanctuary'], ['political', 'culture', 'general', 'hun', 'manet', 'succeeded', 'his', 'father', 'hun', 'sen', 'as', 'prime', 'minister', 'in', 'august', '2023'], ['food', 'stands', 'in', 'siem', 'reap', 'oil', 'and', 'natural', 'gas', 'deposits', 'found', 'beneath', 'cambodia', 's', 'territorial', 'waters', 'in', '2005', 'yield', 'great', 'potential', 'but', 'remain', 'mostly', 'untapped', 'due', 'in', 'part', 'to', 'territorial', 'disputes', 'with', 'thailand']]
# [['on', '22', 'august', '2023', 'hun', 'manet', 'was', 'UNK', 'in', 'as', 'the', 'new', 'cambodian', 'prime', 'minister'], ['folk', 'dances', 'UNK', 'in', 'the', 'villages', 'and', 'are', 'performed', 'for', 'the', 'most', 'part', 'by', 'the', 'villagers', 'for', 'the', 'villagers'], ['and', 'many', 'UNK', 'master', 'UNK', 'from', 'the', 'period', 'were', 'UNK', 'or', 'destroyed'], ['in', '2005', 'cambodia', 'attended', 'the', 'UNK', 'east', 'asia', 'summit', 'in', 'UNK'], ['the', 'UNK', 'are', 'less', 'UNK', 'and', 'the', 'clothing', 'UNK', 'is', 'that', 'of', 'the', 'people', 'the', 'UNK', 'are', 'UNK', 'such', 'as', 'hill', 'UNK', 'UNK', 'or', 'farmers'], ['the', 'mekong', 'and', 'the', 'tonle', 'sap', 'river', 'their', 'numerous', 'UNK', 'and', 'the', 'tonle', 'sap', 'provided', 'UNK', 'of', 'considerable', 'UNK', 'including', 'UNK', 'kilometres', 'navigable', 'all', 'year', 'by', 'craft', 'drawing', '0'], ['improving', 'the', 'lives', 'of', 'at', 'least', 'half', 'a', 'million', 'cambodian', 'workers', 'of', 'factories', 'in', 'the', 'UNK', 'programme', 'and', 'many', 'more', 'of', 'their', 'UNK', 'members', 'UNK'], ['popular', 'games', 'include', 'UNK', 'UNK', 'a', 'UNK', 'which', 'is', 'UNK', 'to', 'a', 'UNK', 'and', 'UNK'], ['the', 'cambodia', 'national', 'UNK', 'team', 'UNK', 'UNK', 'in', 'the', 'UNK', 'asian', 'cup', 'but', 'development', 'has', 'UNK', 'since', 'the', 'civil', 'war'], ['the', 'royal', 'UNK', 'of', 'cambodia', 'total', 'more', 'than', 'UNK', 'personnel']]
# [['UNK', 'UNK', 'koh', 'UNK', 'in', 'cambodia'], ['major', 'UNK', 'UNK', 'include', 'UNK', 'UNK', 'UNK', 'UNK', 'UNK', 'UNK', 'UNK', 'UNK', 'dry', 'beans', 'and', 'rubber'], ['during', 'the', 'late', '1990s', 'and', 'early', '2000s', 'UNK', 'efforts', 'UNK', 'which', 'led', 'to', 'some', 'political', 'stability', 'through', 'a', 'UNK', 'democracy', 'under', 'a', 'constitutional', 'monarchy', 'although', 'sen', 's', 'rule', 'has', 'been', 'UNK', 'by', 'human', 'rights', 'abuses', 'and', 'corruption'], ['the', 'senate', 'has', 'UNK', 'seats', 'two', 'of', 'which', 'are', 'appointed', 'by', 'the', 'king', 'and', 'two', 'others', 'by', 'the', 'national', 'assembly', 'and', 'the', 'rest', 'elected', 'by', 'the', 'commune', 'UNK', 'from', 'the', 'UNK', 'provinces', 'of', 'cambodia'], ['the', 'tourism', 'industry', 'is', 'the', 'country', 's', 'UNK', 'UNK', 'of', 'UNK', 'currency', 'after', 'the', 'UNK', 'industry'], ['tourism', 'was', 'cambodia', 's', 'UNK', 'industry', 'with', 'arrivals', 'increasing', 'from', 'UNK', 'in', '1997', 'to', 'over', '2', 'million', 'in', '2007'], ['in', 'december', 'UNK', 'washington', 'UNK', 'UNK', 'UNK', 'UNK', 'was', 'UNK', 'by', 'sihanouk', 'that', 'if', 'the', 'us', 'UNK', 'to', 'UNK', 'the', 'vietnamese', 'communist', 'sanctuaries', 'he', 'would', 'not', 'UNK', 'UNK', 'cambodians', 'were', 'killed'], ['with', 'increasing', 'economic', 'UNK', 'has', 'come', 'an', 'increase', 'in', 'UNK', 'use', 'though', 'UNK', 'still', 'UNK'], ['in', '2004', 'the', 'number', 'of', 'road', 'UNK', 'per', 'UNK', 'UNK', 'was', 'ten', 'UNK', 'UNK', 'in', 'cambodia', 'than', 'in', 'the', 'developed', 'world', 'and', 'the', 'number', 'of', 'road', 'deaths', 'had', 'UNK', 'in', 'the', 'UNK', 'three', 'years'], ['UNK', 'his', 'father', 's', 'death', 'in', 'UNK', 'sihanouk', 'again', 'became', 'head', 'of', 'state', 'taking', 'the', 'UNK', 'of', 'prince']]

# %%
import pandas as pd 
from collections import Counter 
from nltk.tokenize import word_tokenize
from itertools import chain
# for i in train_tokens:
#     train_corpus = train_tokens[i]+1
# print(train_corpus)
flattened_tokens = list(chain.from_iterable(train_tokens))
word_counts = Counter(flattened_tokens)
tokens = word_tokenize(corpus.lower()) 
df = pd.DataFrame(word_counts.items(),columns=['word','Frequency'])
df = df.sort_values(by='Frequency', ascending=False).reset_index(drop=True)

# Display the DataFrame
print(df)
for word, count in word_counts.items():
    print(f'{word}: {count}')
# Out:
#             word  Frequency
# 0            the        637
# 1             of        333
# 2            and        321
# 3             in        250
# 4             to        171
# ...          ...        ...
# 2656    senators          1
# 2657        1921          1
# 2658  condudcted          1
# 2659        base          1
# 2660   democracy          1
#
# [2661 rows x 2 columns]
# despite: 2
# adopting: 1
# an: 19
# anticorruption: 2
# law: 7
# in: 250
# 2010: 5
# corruption: 8
# prevails: 1
# throughout: 4
# the: 637
# country: 47
# some: 13
# critics: 2
# of: 333
# government: 23
# have: 24
# been: 16
# arrested: 2
# for: 61
# allegedly: 1
# spreading: 1
# fake: 1
# news: 1
# about: 13
# covid19: 2
# pandemic: 2
# cambodia: 155
# hinduism: 5
# has: 36
# left: 3
# little: 1
# trace: 1
# beyond: 1
# magical: 1
# practices: 4
# tantricism: 1
# and: 321
# a: 152
# host: 1
# hindu: 1
# gods: 1
# now: 6
# assimilated: 1
# into: 12
# spirit: 1
# world: 14
# there: 9
# is: 98
# also: 20
# frenchlanguage: 1
# newspaper: 1
# tv: 1
# channels: 1
# are: 54
# available: 2
# french: 8
# after: 18
# 2013: 7
# cambodian: 47
# general: 9
# election: 15
# allegations: 1
# voter: 1
# fraud: 4
# from: 53
# opposition: 9
# party: 19
# national: 27
# rescue: 3
# led: 8
# to: 171
# widespread: 1
# antigovernment: 2
# protests: 3
# that: 37
# continued: 3
# following: 4
# year: 10
# credit: 2
# bureau: 2
# further: 6
# increases: 1
# transparency: 1
# stability: 2
# within: 4
# banking: 3
# sector: 8
# as: 60
# all: 7
# banks: 2
# microfinance: 2
# companies: 3
# required: 1
# by: 80
# report: 4
# accurate: 1
# facts: 1
# figures: 2
# relating: 1
# loan: 1
# performance: 1
# royal: 6
# armed: 4
# forces: 9
# comprised: 1
# 102000: 1
# active: 1
# personnel: 1
# other: 21
# key: 4
# habitats: 2
# include: 6
# evergreen: 2
# dry: 9
# dipterocarp: 1
# forests: 3
# mondolkiri: 1
# province: 11
# protected: 2
# keo: 3
# seima: 1
# wildlife: 7
# sanctuary: 6
# phnom: 27
# prich: 1
# srepok: 1
# well: 4
# ratanakiri: 2
# cardamom: 2
# mountains: 7
# ecosystem: 1
# including: 7
# preah: 6
# monivong: 3
# park: 3
# botumsakor: 1
# aural: 2
# samkos: 1
# political: 9
# culture: 7
# hun: 21
# manet: 3
# succeeded: 2
# his: 22
# father: 3
# sen: 18
# prime: 10
# minister: 14
# august: 4
# 2023: 7
# food: 5
# stands: 2
# siem: 9
# reap: 9
# oil: 2
# natural: 1
# gas: 1
# deposits: 1
# found: 6
# beneath: 2
# s: 77
# territorial: 2
# waters: 1
# 2005: 2
# yield: 1
# great: 1
# potential: 3
# but: 10
# remain: 3
# mostly: 3
# untapped: 1
# due: 6
# part: 9
# disputes: 1
# with: 52
# thailand: 13
# sihanouk: 16
# international: 23
# airport: 7
# coastal: 3
# city: 7
# sihanoukville: 5
# during: 20
# 15day: 1
# festival: 3
# people: 24
# offer: 1
# prayers: 1
# spirits: 4
# their: 17
# dead: 1
# relatives: 2
# iron: 3
# was: 67
# worked: 1
# 500: 1
# bc: 4
# supporting: 2
# evidence: 4
# coming: 1
# khorat: 1
# plateau: 1
# what: 4
# later: 5
# peace: 3
# efforts: 1
# began: 5
# paris: 4
# 1989: 1
# under: 16
# state: 12
# culminating: 1
# 2: 10
# years: 5
# october: 4
# 1991: 2
# comprehensive: 1
# settlement: 1
# july: 2
# human: 3
# rights: 4
# watch: 2
# showed: 1
# numerous: 2
# significant: 4
# vote: 1
# tampering: 1
# june: 2
# 2022: 3
# commune: 1
# elections: 2
# april: 5
# 2016: 3
# assembly: 6
# adopted: 1
# on: 41
# trade: 5
# unions: 1
# agriculture: 6
# remains: 2
# dominant: 1
# economic: 4
# growth: 5
# textiles: 2
# construction: 2
# garments: 1
# tourism: 7
# leading: 2
# increased: 7
# foreign: 12
# investment: 7
# plan: 3
# makes: 2
# provision: 1
# establishing: 2
# science: 3
# technology: 2
# foundation: 1
# promote: 1
# industrial: 3
# innovation: 2
# particular: 3
# focus: 1
# primary: 4
# industry: 6
# icts: 1
# chinese: 6
# company: 1
# support: 4
# liberation: 2
# army: 4
# built: 3
# deepwater: 1
# seaport: 1
# along: 4
# 90: 2
# km: 1
# stretch: 1
# coastline: 2
# gulf: 4
# koh: 1
# kong: 1
# port: 2
# sufficiently: 1
# deep: 2
# be: 15
# used: 6
# cruise: 1
# ships: 3
# bulk: 1
# carriers: 1
# or: 20
# warships: 1
# public: 5
# refuted: 1
# right: 2
# u: 1
# worst: 1
# health: 5
# indicators: 1
# 22: 2
# its: 23
# quality: 3
# varies: 1
# widely: 2
# it: 27
# often: 10
# infused: 1
# fruits: 2
# medicinal: 1
# herbs: 1
# son: 7
# deemed: 3
# independent: 1
# media: 3
# politicians: 1
# neither: 1
# free: 3
# nor: 1
# fair: 2
# officially: 1
# kingdom: 16
# southeast: 13
# asia: 8
# indochinese: 1
# peninsula: 1
# highly: 1
# vulnerable: 3
# negative: 2
# effects: 2
# climate: 8
# change: 5
# advised: 1
# focuses: 1
# more: 13
# developing: 2
# renewable: 5
# energy: 7
# mitigation: 1
# measures: 1
# throne: 4
# became: 6
# vacant: 1
# 1941: 2
# death: 4
# sisowath: 3
# france: 5
# passed: 1
# over: 8
# monireth: 1
# feeling: 1
# he: 7
# too: 1
# independently: 1
# minded: 1
# known: 7
# formally: 1
# robam: 1
# reach: 1
# troap: 1
# set: 2
# music: 4
# pinpeat: 1
# ensemble: 1
# accompanied: 1
# vocal: 1
# chorus: 1
# this: 16
# shift: 1
# english: 3
# relationships: 1
# replaced: 2
# both: 8
# stamps: 1
# since: 9
# 2002: 2
# currency: 1
# mahayana: 2
# buddhism: 8
# religion: 8
# majority: 5
# vietnamese: 15
# 2014: 1
# tribunal: 3
# sentenced: 1
# khieu: 1
# samphan: 1
# regime: 5
# 83yearold: 1
# former: 4
# head: 1
# nuon: 2
# chea: 2
# 88yearold: 1
# chief: 1
# ideologue: 1
# life: 2
# prison: 2
# war: 7
# crimes: 3
# charges: 1
# role: 2
# terror: 1
# period: 9
# 1970s: 2
# boat: 3
# racing: 1
# bon: 2
# om: 2
# touk: 2
# annual: 4
# rowing: 1
# contest: 1
# most: 23
# attended: 1
# penh: 22
# busiest: 1
# education: 17
# system: 10
# heavily: 2
# decentralised: 1
# three: 5
# levels: 2
# central: 6
# provincial: 1
# district: 1
# responsible: 6
# management: 2
# lyrics: 1
# usually: 1
# moral: 1
# religious: 5
# theme: 1
# cpp: 6
# won: 3
# every: 4
# seat: 2
# without: 1
# major: 3
# effectively: 2
# solidifying: 1
# de: 5
# facto: 5
# oneparty: 3
# rule: 2
# making: 3
# garment: 5
# factories: 1
# safer: 2
# overall: 1
# f: 1
# administrative: 4
# divisions: 4
# main: 25
# article: 15
# autonomous: 2
# municipality: 2
# provinces: 7
# firstlevel: 1
# defense: 2
# tea: 7
# banh: 1
# established: 5
# diplomatic: 1
# relations: 4
# countries: 6
# reports: 2
# twenty: 1
# embassies: 1
# many: 7
# asian: 7
# neighbours: 2
# those: 5
# important: 7
# players: 1
# negotiations: 1
# us: 8
# australia: 1
# canada: 1
# china: 6
# european: 1
# union: 3
# japan: 1
# russia: 1
# ranked: 1
# 103rd: 1
# global: 3
# index: 2
# 2024: 2
# vietnam: 13
# extended: 1
# 1965: 1
# via: 2
# ho: 2
# chi: 2
# minh: 2
# trails: 1
# 1: 12
# 2281951: 1
# 11: 1
# chbar: 1
# mon: 1
# kampong: 9
# speu: 1
# 50359: 1
# battambang: 7
# sisophon: 4
# 245494: 1
# 12: 2
# bavet: 1
# svay: 3
# rieng: 3
# 43783: 1
# 3: 6
# 119251: 1
# 13: 1
# doun: 1
# kaev: 1
# takéo: 1
# 43402: 1
# 4: 5
# banteay: 3
# meanchey: 5
# 99019: 1
# 14: 3
# 41424: 1
# 5: 4
# poipet: 1
# 98934: 1
# 15: 1
# chhnang: 3
# 41080: 1
# 6: 5
# ta: 2
# khmau: 1
# kandal: 1
# 75629: 1
# 16: 1
# cham: 8
# 38365: 1
# 7: 5
# 73036: 1
# 17: 2
# pailin: 3
# 37393: 1
# 8: 2
# samraong: 1
# oddar: 2
# 70944: 1
# 18: 2
# prey: 3
# veng: 2
# 36254: 1
# 9: 3
# pursat: 3
# 58355: 1
# 19: 1
# suong: 1
# tboung: 1
# khmum: 1
# 35054: 1
# 10: 4
# stueng: 1
# saen: 1
# thom: 2
# 53118: 1
# 20: 3
# kampot: 3
# 32053: 1
# languages: 3
# see: 2
# demographics: 3
# khmer: 46
# language: 9
# member: 6
# monkhmer: 3
# subfamily: 1
# austroasiatic: 1
# group: 4
# fear: 1
# renewed: 1
# instability: 2
# discourage: 1
# delay: 1
# aid: 3
# although: 3
# bilateral: 1
# multilateral: 1
# donors: 2
# demonstrators: 1
# were: 26
# injured: 2
# killed: 2
# where: 5
# reported: 5
# 20000: 1
# protesters: 2
# gathered: 1
# clashing: 1
# riot: 1
# police: 3
# visitor: 1
# arrivals: 1
# 2018: 4
# topped: 1
# six: 2
# million: 12
# tenfold: 1
# increase: 2
# beginning: 2
# 21st: 1
# century: 4
# waterfall: 1
# at: 17
# kulen: 1
# lang: 1
# forest: 13
# rate: 6
# deforestation: 3
# one: 11
# highest: 4
# perceived: 1
# destructive: 1
# singular: 1
# environmental: 4
# issue: 1
# king: 13
# urged: 1
# followers: 2
# help: 2
# overthrowing: 1
# hastening: 1
# onset: 1
# civil: 4
# they: 8
# handled: 1
# record: 2
# passengers: 1
# kâmpŭchéa: 1
# shortened: 1
# alternative: 1
# official: 7
# name: 5
# ពររជណចករកមពជ: 1
# कमबज: 1
# referring: 1
# descendants: 2
# kambu: 2
# only: 7
# men: 2
# aged: 2
# 60: 1
# counted: 1
# purpose: 2
# collection: 1
# taxes: 1
# rural: 6
# populations: 1
# particularly: 4
# risk: 2
# enthroned: 2
# 29: 1
# 2004: 6
# could: 3
# supported: 1
# population: 18
# up: 5
# united: 6
# nations: 8
# asean: 5
# rcep: 1
# east: 3
# summit: 2
# wto: 1
# nonaligned: 1
# movement: 1
# la: 2
# francophonie: 2
# dialogue: 1
# partner: 1
# shanghai: 1
# cooperation: 2
# organisation: 1
# history: 5
# prehistory: 2
# early: 6
# glazed: 1
# stoneware: 1
# dating: 1
# back: 2
# 12th: 2
# exists: 1
# pleistocene: 1
# occupation: 3
# which: 21
# includes: 3
# quartz: 1
# quartzite: 1
# pebble: 1
# tools: 1
# terraces: 1
# mekong: 13
# river: 8
# stung: 1
# treng: 1
# kratié: 1
# secretaries: 1
# chay: 1
# saing: 1
# yun: 1
# por: 1
# bun: 2
# sreu: 1
# choeung: 1
# ek: 1
# site: 3
# mass: 4
# grave: 1
# genocide: 3
# victims: 3
# rouge: 19
# era: 3
# estimates: 2
# how: 2
# range: 2
# approximately: 3
# cited: 2
# figure: 1
# typically: 1
# fasterpaced: 1
# than: 8
# classical: 2
# dance: 6
# folk: 3
# dances: 7
# display: 1
# themes: 1
# common: 1
# person: 3
# such: 8
# love: 1
# comedy: 1
# warding: 1
# off: 3
# evil: 1
# first: 7
# half: 1
# exports: 3
# worth: 1
# department: 1
# says: 1
# committed: 3
# frequent: 1
# largescale: 1
# abuses: 1
# extrajudicial: 1
# killings: 1
# torture: 1
# impunity: 2
# southern: 4
# region: 7
# adjoining: 1
# narrow: 1
# lowland: 1
# strip: 1
# wooded: 1
# sparsely: 1
# populated: 1
# isolated: 2
# plain: 5
# southwestern: 3
# highlands: 3
# 2000: 4
# become: 1
# absorbed: 1
# influences: 1
# india: 2
# passing: 1
# them: 3
# civilisations: 1
# laos: 5
# western: 5
# while: 11
# kampuchea: 9
# eastern: 2
# angkor: 9
# wat: 4
# historical: 2
# beaches: 2
# capital: 4
# 150: 2
# casinos: 1
# attractions: 1
# tourists: 4
# cambodians: 11
# 0: 4
# two: 8
# distinct: 3
# seasons: 1
# developed: 2
# spread: 5
# empire: 10
# distinctive: 2
# styles: 3
# architecture: 3
# sculpture: 1
# exchanged: 1
# neighbouring: 2
# reputation: 1
# safe: 1
# destination: 1
# hindered: 1
# unrest: 1
# several: 5
# highprofile: 1
# examples: 3
# serious: 1
# crime: 3
# against: 5
# visiting: 1
# cyclo: 1
# cycle: 1
# rickshaws: 2
# popular: 12
# 1990s: 2
# increasingly: 1
# remorques: 1
# imported: 2
# sole: 2
# dominantparty: 1
# provided: 2
# no: 2
# protection: 1
# whistleblowers: 2
# can: 6
# jailed: 1
# months: 1
# if: 2
# not: 8
# proven: 1
# according: 6
# unexploded: 1
# land: 7
# mines: 1
# 60000: 1
# civilian: 1
# deaths: 1
# thousands: 4
# maimed: 1
# 1970: 2
# exact: 1
# origins: 1
# disputed: 3
# dengue: 1
# fever: 1
# rock: 1
# roll: 1
# band: 2
# features: 1
# female: 4
# singer: 2
# backup: 1
# california: 1
# 28: 1
# march: 2
# press: 3
# conference: 1
# held: 3
# appealed: 1
# i: 2
# appeal: 1
# you: 1
# publicise: 1
# abroad: 1
# very: 2
# clear: 3
# stand: 1
# cambodiathat: 1
# will: 2
# any: 3
# case: 1
# oppose: 1
# bombings: 1
# territory: 2
# whatever: 1
# pretext: 1
# commercial: 2
# airports: 1
# pol: 3
# pot: 3
# determined: 2
# keep: 1
# power: 12
# disenfranchise: 1
# enemies: 2
# threats: 1
# thus: 2
# violent: 1
# aggressive: 1
# actions: 2
# spans: 1
# area: 8
# 181035: 2
# square: 5
# kilometres: 8
# trains: 2
# again: 2
# running: 1
# destinations: 2
# south: 4
# 802: 1
# ad: 1
# jayavarman: 1
# ii: 1
# declared: 1
# himself: 1
# uniting: 1
# warring: 1
# princes: 1
# chenla: 4
# kambuja: 1
# senate: 4
# president: 6
# gives: 1
# him: 4
# sign: 2
# laws: 1
# absence: 1
# un: 5
# designates: 1
# least: 2
# cultivated: 1
# ties: 2
# 2010s: 3
# simultaneous: 1
# attacks: 4
# around: 9
# perimeter: 1
# pinned: 1
# down: 3
# republican: 1
# cpk: 1
# units: 2
# overran: 2
# fire: 1
# bases: 1
# controlling: 1
# vital: 1
# lower: 4
# resupply: 1
# route: 2
# attract: 1
# improve: 3
# governance: 1
# adopt: 1
# targets: 1
# develop: 1
# effective: 1
# regulatory: 3
# framework: 2
# project: 2
# bankability: 1
# facilitate: 1
# market: 1
# entry: 2
# investors: 2
# journalists: 1
# covering: 1
# protest: 1
# results: 2
# september: 2
# say: 1
# deliberately: 1
# attacked: 1
# clothes: 1
# slingshots: 1
# stun: 1
# guns: 1
# ranariddh: 7
# ousted: 3
# fled: 2
# opponents: 2
# tortured: 1
# summarily: 1
# executed: 2
# ministry: 5
# youth: 4
# sports: 4
# approved: 1
# policy: 5
# research: 6
# development: 9
# instead: 1
# norodom: 12
# maternal: 1
# grandson: 1
# burials: 1
# testify: 1
# improvement: 2
# availability: 1
# existence: 1
# social: 7
# structure: 2
# labour: 5
# organization: 2
# age: 5
# settlements: 1
# baksei: 1
# chamkrong: 1
# angkorian: 4
# temples: 4
# circular: 2
# earthworks: 2
# discovered: 3
# lovea: 1
# northwest: 3
# traditionally: 3
# offered: 2
# wats: 1
# providing: 1
# exclusively: 1
# male: 4
# archaeological: 3
# records: 1
# between: 12
# holocene: 2
# equally: 1
# limited: 1
# municipalities: 3
# districts: 3
# secondlevel: 1
# ministerial: 1
# appointees: 1
# exercise: 1
# executive: 3
# dissolved: 3
# ahead: 1
# ruling: 2
# enacted: 1
# tighter: 1
# curbs: 1
# 2007: 2
# team: 1
# researchers: 1
# using: 4
# satellite: 1
# photographs: 1
# modern: 6
# techniques: 1
# concluded: 1
# had: 7
# largest: 5
# preindustrial: 1
# urban: 3
# sprawl: 1
# 2980: 1
# center: 1
# considered: 2
# alongside: 1
# philippines: 2
# number: 5
# landmine: 1
# casualties: 1
# sharply: 1
# decreased: 1
# 800: 1
# 111: 1
# junction: 1
# bassac: 1
# tonle: 9
# sap: 9
# rivers: 2
# capable: 1
# receiving: 1
# 8000ton: 1
# wet: 2
# season: 8
# 5000ton: 1
# creating: 1
# level: 2
# playing: 1
# field: 3
# across: 3
# g: 1
# 1978: 2
# entire: 1
# legal: 4
# eradicated: 1
# among: 2
# 65: 2
# ratio: 3
# map: 5
# indochina: 4
# 1760: 1
# hill: 1
# tribe: 1
# hunted: 1
# incessantly: 1
# carried: 3
# slaves: 1
# siamese: 1
# annamites: 1
# geographical: 1
# feature: 1
# inundations: 1
# measuring: 1
# 2590: 1
# expanding: 1
# 24605: 1
# rainy: 2
# funcinpec: 2
# hung: 1
# parliament: 3
# quantity: 1
# souvenirs: 1
# produced: 2
# sufficient: 1
# face: 2
# increasing: 2
# products: 2
# sold: 1
# markets: 1
# te: 2
# krolap: 1
# strong: 2
# made: 3
# putting: 1
# water: 2
# leaves: 2
# small: 1
# glass: 1
# placing: 1
# saucer: 1
# top: 2
# turning: 1
# whole: 1
# thing: 1
# upside: 1
# brew: 1
# addition: 1
# oppression: 2
# accused: 3
# sale: 1
# vast: 2
# areas: 8
# resulting: 1
# eviction: 1
# villagers: 1
# taking: 1
# bribes: 3
# exchange: 2
# grants: 2
# exploit: 1
# wealth: 1
# mineral: 1
# resources: 3
# per: 8
# 100000: 2
# demonstrations: 1
# bestpreserved: 1
# example: 1
# hundreds: 2
# landscape: 1
# characterised: 1
# lowlying: 1
# surrounded: 1
# uplands: 1
# low: 1
# upper: 2
# reaches: 1
# delta: 1
# policies: 1
# guidelines: 1
# bank: 7
# monetary: 1
# fund: 2
# suffered: 1
# setbacks: 1
# child: 1
# study: 1
# kim: 1
# employed: 1
# children: 6
# enrolled: 1
# school: 2
# employment: 1
# associated: 1
# late: 2
# impacts: 1
# learning: 1
# outcomes: 2
# drop: 1
# out: 6
# rates: 1
# billion: 2
# accounting: 2
# almost: 3
# ten: 2
# cent: 2
# gross: 1
# product: 1
# 443kilometre: 1
# vowed: 1
# until: 7
# turned: 1
# 74: 1
# nva: 2
# positions: 1
# communist: 2
# expanded: 1
# lines: 3
# communication: 1
# rich: 1
# fisheries: 2
# freshwater: 3
# lake: 4
# largely: 3
# supply: 6
# impoverished: 1
# protein: 1
# 1904: 1
# manipulated: 1
# choice: 1
# brother: 1
# placed: 1
# 39: 1
# 12800000: 1
# pop: 2
# experiences: 1
# heaviest: 1
# precipitation: 1
# driest: 1
# occurring: 1
# january: 2
# february: 1
# demanded: 1
# operating: 2
# when: 11
# obtaining: 3
# licences: 1
# permits: 4
# constructionrelated: 2
# lawyers: 3
# did: 1
# reappear: 1
# 1995: 1
# bar: 1
# association: 2
# created: 3
# 1962: 4
# 5728771: 1
# 1980: 1
# 6600000: 1
# new: 10
# strategy: 1
# action: 1
# implemented: 1
# contains: 2
# ideas: 1
# incite: 1
# green: 2
# environmentally: 1
# sustainable: 1
# acclaimed: 1
# universities: 3
# based: 2
# metres: 2
# another: 4
# 282: 1
# navigable: 1
# craft: 1
# drawing: 1
# growing: 3
# microbreweries: 1
# response: 2
# north: 6
# invasion: 1
# richard: 1
# nixon: 1
# announced: 3
# ground: 1
# entered: 1
# campaign: 1
# aimed: 1
# destroying: 1
# base: 1
# protectorate: 3
# condudcted: 1
# census: 5
# 1921: 1
# senators: 1
# serve: 1
# sixyear: 1
# terms: 3
# lack: 3
# distinction: 1
# courts: 1
# branch: 1
# politicisation: 1
# judicial: 1
# profession: 3
# 1932: 1
# documents: 1
# uncovered: 1
# soviet: 2
# archives: 1
# reveal: 1
# attempt: 1
# overrun: 1
# launched: 4
# explicit: 1
# request: 1
# negotiated: 1
# then: 3
# second: 4
# command: 3
# institute: 3
# university: 3
# 2019: 3
# estimated: 4
# 88: 1
# marked: 2
# currently: 4
# commands: 1
# 120: 1
# 125: 1
# seats: 2
# 55: 1
# 62: 1
# techo: 1
# intended: 1
# replace: 1
# existing: 2
# refusal: 1
# withdraw: 1
# sanctions: 1
# constitutionally: 1
# multiparty: 1
# dominates: 1
# 2017: 4
# rail: 3
# totalling: 1
# 612: 2
# single: 1
# onemetre: 1
# gauge: 1
# track: 1
# easily: 1
# landslide: 1
# flawed: 1
# disqualification: 1
# candlelight: 1
# besides: 1
# phom: 1
# tourist: 2
# southwest: 1
# stops: 1
# backpackers: 1
# who: 7
# make: 1
# portion: 2
# visitors: 1
# signed: 2
# treaty: 1
# prohibition: 1
# nuclear: 1
# weapons: 1
# eventually: 1
# displaced: 1
# 1295: 1
# indravarman: 1
# iii: 1
# took: 1
# gave: 1
# rise: 3
# term: 3
# killing: 2
# fields: 1
# tuol: 2
# sleng: 2
# articles: 4
# ko: 1
# 19thcentury: 1
# illustration: 1
# tale: 1
# vorvong: 1
# sorvong: 1
# various: 6
# factors: 1
# contribute: 1
# theravada: 2
# colonialism: 1
# globalization: 1
# rice: 9
# wine: 1
# alcoholic: 1
# drink: 2
# like: 3
# apsara: 1
# icons: 1
# mahori: 1
# ensembles: 1
# accompany: 1
# die: 1
# before: 3
# five: 1
# event: 2
# penetration: 1
# farmers: 1
# third: 2
# millennium: 2
# basketball: 1
# volleyball: 2
# bodybuilding: 1
# hockey: 1
# rugby: 1
# golf: 1
# baseball: 1
# gaining: 1
# popularity: 2
# muslims: 1
# fish: 7
# so: 1
# livelihoods: 1
# economically: 1
# nutritionally: 1
# said: 2
# gordon: 1
# holtgrieve: 1
# professor: 1
# washington: 1
# points: 1
# none: 1
# dams: 1
# either: 2
# being: 7
# pointing: 1
# good: 1
# warning: 1
# comes: 2
# lawsuit: 1
# filed: 1
# committee: 1
# deputy: 1
# chhay: 1
# accusing: 1
# defamation: 1
# speaking: 1
# electoral: 2
# viet: 1
# cong: 1
# desperate: 1
# retain: 1
# sanctuaries: 2
# fertility: 2
# mondol: 1
# kiri: 2
# rattanak: 1
# women: 4
# average: 3
# commander: 2
# originally: 1
# installed: 1
# maintains: 1
# man: 3
# position: 2
# violence: 2
# necessary: 1
# woman: 2
# confiscated: 1
# decade: 1
# selfenrichment: 1
# maintaining: 1
# groups: 7
# special: 2
# interests: 1
# hosted: 1
# ganefo: 1
# games: 3
# 1966: 1
# recently: 2
# sea: 1
# withdrew: 1
# 1993: 5
# decided: 1
# registered: 1
# voters: 1
# 1980s: 3
# commodity: 1
# few: 2
# sources: 1
# tra: 2
# leaf: 1
# books: 2
# legends: 1
# ramayana: 1
# origin: 2
# prayer: 1
# 15th: 2
# decline: 1
# 1863: 1
# literacy: 1
# 89: 1
# compared: 2
# 86: 1
# females: 1
# economist: 1
# imf: 1
# gdp: 3
# 20012010: 1
# etymology: 1
# names: 1
# japanese: 2
# gained: 2
# independence: 2
# 1953: 3
# cultural: 3
# connections: 1
# peoples: 1
# because: 5
# khmers: 3
# influenced: 3
# indian: 2
# sphere: 2
# nearly: 2
# dark: 1
# enough: 1
# decanted: 1
# cup: 1
# plenty: 2
# sugar: 3
# added: 1
# milk: 1
# historically: 2
# lived: 1
# near: 2
# contiguous: 1
# diagonal: 1
# arc: 1
# modernday: 2
# meet: 1
# way: 2
# mouth: 1
# southeastern: 1
# office: 1
# lao: 1
# pdr: 1
# noted: 1
# concerns: 3
# gaps: 1
# same: 2
# message: 1
# conveyed: 1
# johnson: 1
# emissary: 1
# chester: 1
# bowles: 1
# 1968: 1
# prehistoric: 1
# red: 3
# soils: 1
# memot: 1
# adjacent: 1
# latter: 1
# 1950s: 1
# high: 4
# series: 5
# wars: 1
# kingdoms: 1
# sacked: 1
# ayutthaya: 1
# abandoned: 1
# 1432: 1
# ecological: 1
# failure: 1
# infrastructure: 4
# breakdown: 1
# yai: 1
# performed: 3
# solo: 1
# comedic: 1
# nature: 2
# rank: 1
# representative: 2
# thiounn: 1
# prasith: 1
# retained: 1
# work: 2
# consultation: 1
# representatives: 1
# noncommunist: 1
# parties: 3
# influencing: 1
# business: 2
# through: 3
# factory: 1
# data: 1
# highlight: 1
# core: 1
# strategies: 1
# brandsbuyers: 1
# consistently: 1
# listed: 1
# corrupt: 2
# governments: 2
# surath: 1
# others: 1
# legacy: 1
# classic: 2
# singers: 3
# remaking: 1
# songs: 1
# slavery: 1
# 256800: 1
# enslaved: 1
# powersharing: 1
# agreement: 1
# agreed: 1
# simultaneously: 2
# coprime: 3
# ministers: 1
# threatened: 2
# secede: 1
# fully: 2
# transferred: 1
# 96: 1
# 1998: 2
# 11437656: 1
# forced: 1
# evictions: 1
# senior: 1
# officials: 2
# security: 1
# governmentconnected: 1
# leaders: 2
# commonplace: 3
# sex: 2
# workers: 2
# northeast: 1
# monsoon: 1
# ushers: 1
# lasts: 2
# november: 5
# composed: 1
# breweries: 1
# located: 1
# mainly: 1
# souvenir: 1
# employs: 2
# lot: 1
# places: 1
# interest: 1
# seven: 2
# ministries: 1
# 33: 1
# these: 2
# institutions: 5
# come: 2
# umbrella: 1
# indianised: 2
# facilitated: 1
# undertook: 1
# infrastructural: 1
# projects: 1
# sihamoni: 4
# selected: 1
# ninemember: 1
# council: 2
# selection: 2
# process: 2
# quickly: 1
# put: 2
# place: 1
# abdication: 2
# week: 2
# prior: 1
# section: 1
# needs: 2
# updated: 1
# unusual: 1
# disappears: 1
# expands: 1
# massively: 1
# flow: 2
# backs: 1
# rains: 1
# dwellers: 1
# engaged: 1
# primarily: 1
# commerce: 1
# preangkorian: 1
# postangkor: 2
# funan: 2
# faces: 1
# bodhisattva: 1
# avalokiteshvara: 1
# prasat: 1
# bayon: 1
# 3rd: 1
# 4th: 1
# 5th: 1
# centuries: 2
# states: 2
# successor: 1
# coalesced: 1
# far: 1
# sport: 1
# disastrous: 1
# flooding: 2
# occurred: 1
# 2001: 1
# degree: 1
# information: 7
# homicide: 1
# circle: 1
# romvong: 1
# romkbach: 1
# saravan: 1
# lam: 1
# leav: 1
# run: 1
# supreme: 2
# court: 3
# paving: 1
# return: 1
# yet: 2
# authoritarian: 1
# adults: 1
# survive: 1
# landmines: 2
# require: 1
# amputation: 1
# limbs: 1
# resort: 1
# begging: 1
# survival: 1
# ruler: 2
# leadership: 1
# cuisine: 2
# relatively: 2
# unknown: 1
# 94: 1
# statistics: 1
# chapter: 1
# p: 1
# jobs: 1
# affected: 2
# directive: 2
# banning: 1
# finance: 3
# issuing: 1
# online: 2
# gambling: 2
# licenses: 5
# operators: 1
# holding: 1
# would: 1
# allowed: 2
# continue: 1
# expire: 1
# revolution: 1
# 1960s: 1
# murdered: 1
# starved: 1
# overwork: 1
# issued: 1
# appointed: 1
# advice: 1
# approval: 1
# consisted: 1
# royalist: 1
# faction: 1
# front: 1
# unbacked: 1
# sought: 1
# investigate: 1
# democratic: 3
# prosecute: 1
# 2020: 5
# newly: 2
# governmentinexile: 1
# referred: 1
# coalition: 1
# formed: 2
# 1981: 1
# factions: 1
# already: 1
# use: 4
# europe: 1
# 1524: 1
# antonio: 1
# pigafetta: 1
# cites: 1
# relazione: 1
# del: 1
# primo: 1
# viaggio: 1
# intorno: 1
# al: 1
# mondo: 1
# camogia: 1
# able: 1
# stabilize: 1
# accepted: 1
# 30: 1
# 1999: 1
# monarchy: 2
# restored: 1
# reinstated: 1
# postwar: 1
# coordinated: 1
# untac: 2
# reign: 2
# result: 2
# charitable: 1
# organisations: 2
# assisted: 1
# worldwide: 1
# recognises: 2
# terrestrial: 1
# ecoregions: 1
# rain: 1
# annamite: 1
# tropical: 4
# swamp: 2
# sapmekong: 1
# peat: 1
# continues: 1
# challenges: 2
# past: 2
# improvements: 1
# especially: 3
# net: 1
# enrolment: 1
# gains: 1
# introduction: 2
# program: 1
# basedbudgeting: 1
# helps: 1
# disadvantaged: 1
# gain: 2
# access: 2
# instituted: 1
# cult: 1
# godking: 1
# conquests: 1
# flourished: 1
# 9th: 1
# revised: 1
# prelude: 1
# reorganisation: 1
# military: 3
# script: 2
# derived: 1
# pallava: 1
# function: 1
# still: 3
# debated: 1
# possibly: 1
# date: 1
# paddy: 1
# provides: 1
# oversight: 2
# direct: 2
# robert: 1
# d: 1
# practised: 3
# 95: 2
# 4392: 1
# monastery: 1
# 2015: 1
# 100: 1
# ownership: 1
# constitution: 1
# promulgates: 1
# compulsory: 1
# nine: 2
# guaranteeing: 1
# universal: 1
# basic: 2
# vietnameseoccupied: 1
# republic: 4
# populous: 1
# move: 1
# represented: 2
# step: 1
# towards: 1
# approach: 1
# application: 1
# purposes: 1
# 04: 1
# femalebiased: 1
# greater: 2
# subregion: 2
# ruled: 1
# 1975: 2
# 1979: 2
# cambodianvietnamese: 2
# saw: 2
# defence: 2
# form: 3
# subordinate: 1
# departments: 1
# logistics: 2
# materials: 1
# technical: 2
# services: 5
# headquarters: 1
# recent: 2
# artistic: 1
# sinn: 1
# sisamouth: 1
# ros: 1
# serey: 1
# sothea: 1
# introduced: 1
# musical: 1
# muslim: 1
# 80: 2
# ethnic: 6
# even: 1
# though: 1
# attracted: 1
# much: 5
# serves: 1
# model: 1
# learn: 1
# conducting: 1
# solar: 2
# auctions: 1
# reporters: 1
# sustained: 1
# minor: 1
# injuries: 2
# hit: 1
# slingshot: 1
# projectiles: 1
# hospitalized: 1
# operation: 1
# eagle: 1
# pull: 1
# rebels: 1
# exploded: 1
# ordnance: 1
# alone: 2
# caused: 1
# 44630: 1
# mineuxo: 1
# victim: 1
# wear: 1
# krama: 1
# scarf: 1
# unique: 2
# aspect: 1
# clothing: 1
# day: 3
# troops: 3
# offensive: 1
# 117: 1
# days: 1
# collapse: 1
# regular: 1
# cities: 1
# restarted: 1
# offering: 1
# option: 1
# road: 3
# travellers: 1
# grown: 1
# mondulkiri: 1
# kirirom: 1
# shows: 1
# communities: 1
# huntergatherers: 1
# inhabited: 1
# ancient: 1
# discovery: 1
# cave: 1
# laang: 1
# spean: 1
# belongs: 2
# hoabinhian: 1
# prosoviet: 1
# kampuchean: 1
# revolutionary: 1
# 1951: 1
# avoid: 1
# purged: 1
# mok: 1
# degradation: 1
# parks: 1
# large: 1
# scale: 1
# endangered: 1
# endemic: 1
# species: 7
# extinction: 1
# loss: 1
# probably: 1
# dine: 2
# dish: 1
# kuyteav: 1
# pork: 3
# broth: 1
# noodle: 1
# soup: 1
# fried: 1
# garlic: 1
# scallions: 1
# onions: 1
# may: 1
# contain: 2
# toppings: 1
# beef: 1
# balls: 1
# shrimp: 1
# liver: 1
# lettuce: 1
# steadily: 1
# each: 3
# stable: 1
# tonlé: 1
# diet: 1
# nevertheless: 1
# pleas: 1
# ignored: 1
# bombing: 1
# professionals: 2
# doctors: 1
# teachers: 1
# targeted: 2
# 26: 3
# workforce: 1
# translates: 1
# roughly: 1
# deal: 2
# extensive: 2
# tape: 1
# demand: 1
# majesty: 1
# holds: 1
# commanderinchief: 1
# 1987: 1
# passenger: 2
# train: 2
# operated: 2
# 141: 1
# funded: 2
# started: 1
# revitalise: 1
# languishing: 1
# centers: 1
# bangkok: 1
# buddhist: 1
# destroyed: 1
# style: 2
# instruments: 2
# mixture: 1
# traditional: 3
# open: 1
# doors: 1
# yielded: 1
# coterie: 1
# cronies: 1
# wife: 1
# rany: 1
# megha: 1
# bahree: 1
# writer: 1
# forbes: 1
# analogous: 1
# excavations: 1
# layers: 1
# radiocarbon: 1
# dates: 1
# 6000: 1
# abuts: 1
# sandstone: 1
# escarpment: 1
# forms: 1
# southwardfacing: 1
# cliff: 1
# stretching: 1
# 200: 1
# miles: 1
# west: 1
# rising: 1
# abruptly: 1
# above: 1
# heights: 1
# 600: 1
# 1800: 1
# feet: 2
# indigenous: 1
# collectively: 1
# montagnards: 1
# loeu: 2
# meaning: 1
# highland: 2
# centre: 1
# capitals: 1
# constructed: 1
# zenith: 1
# 1874: 1
# total: 3
# 946000: 1
# prahok: 1
# longer: 1
# storage: 1
# guests: 1
# banquets: 1
# informal: 1
# gatherings: 1
# facing: 1
# fact: 2
# older: 2
# lacks: 1
# countryside: 1
# suffers: 1
# pledged: 1
# 504: 1
# 850: 2
# loans: 1
# assistance: 1
# crowned: 1
# 2012: 2
# regulated: 1
# 31: 1
# covered: 3
# entities: 2
# 70: 1
# individual: 1
# underlining: 1
# 20102015: 1
# significantly: 1
# invested: 1
# vocational: 1
# tackle: 1
# poverty: 1
# unemployment: 1
# foreigners: 1
# cheat: 1
# inside: 1
# outside: 1
# justifying: 1
# care: 2
# private: 1
# practitioners: 1
# trust: 1
# providers: 1
# factor: 1
# improving: 1
# uptake: 1
# köppen: 1
# classification: 1
# rest: 1
# dominated: 1
# monsoons: 1
# distinctly: 1
# seasonal: 2
# differences: 1
# please: 1
# update: 1
# reflect: 1
# events: 1
# thenprime: 1
# meets: 1
# joe: 1
# biden: 1
# crackdowns: 2
# geography: 2
# geographic: 1
# regional: 1
# lies: 1
# entirely: 1
# tropics: 1
# latitudes: 1
# 15n: 1
# longitudes: 1
# 102: 1
# 108e: 1
# colloquially: 1
# refer: 1
# srok: 1
# slightly: 1
# formal: 1
# បរទសកមពជ: 1
# pchum: 2
# ben: 2
# ancestors: 2
# celebrated: 1
# buddhists: 1
# economy: 2
# grew: 1
# rapidly: 1
# 2000s: 1
# received: 1
# considerable: 1
# belt: 1
# initiative: 2
# cover: 1
# 46: 1
# equivalent: 1
# 8068370: 1
# hectares: 4
# 11004790: 1
# 1990: 1
# arms: 2
# came: 2
# speakers: 3
# australian: 1
# hip: 1
# hop: 1
# astronomy: 1
# class: 2
# recorded: 4
# kak: 1
# channthy: 1
# nativeborn: 1
# 1997: 4
# fearing: 1
# prince: 2
# coup: 3
# purge: 1
# supporters: 1
# upland: 1
# blocks: 1
# krâvanh: 1
# dâmrei: 1
# covers: 1
# détat: 2
# consolidated: 2
# sung: 1
# duo: 1
# take: 1
# turns: 1
# answering: 1
# verse: 1
# posing: 1
# riddles: 1
# solve: 1
# short: 1
# instrumental: 1
# breaks: 1
# verses: 1
# programme: 1
# engages: 1
# employers: 1
# working: 1
# conditions: 1
# boost: 1
# competitiveness: 1
# biodiversity: 3
# contained: 1
# surrounding: 1
# biosphere: 2
# once: 2
# landmined: 1
# beans: 1
# roasted: 1
# butter: 1
# plus: 1
# ingredients: 1
# might: 1
# anything: 1
# rum: 1
# fat: 1
# giving: 1
# beverage: 1
# strange: 1
# sometimes: 2
# faintly: 1
# chocolatey: 1
# aroma: 1
# naturally: 1
# regenerating: 1
# 7464400: 1
# planted: 1
# 603970: 1
# deeply: 1
# native: 2
# animism: 1
# combination: 1
# disrespecting: 1
# thai: 1
# upbuild: 1
# situation: 1
# unsettled: 1
# literate: 1
# shared: 2
# generally: 2
# severe: 2
# impact: 1
# travel: 1
# restrictions: 1
# conflict: 1
# shaken: 1
# minimising: 1
# disease: 1
# strain: 1
# outbreak: 1
# 2021: 2
# prompted: 1
# lockdowns: 1
# islam: 1
# followed: 3
# varieties: 2
# malays: 1
# resident: 1
# generations: 1
# prostitution: 2
# illegal: 1
# appears: 1
# prevalent: 1
# temperatures: 1
# 40: 1
# c: 1
# dissent: 2
# described: 1
# educational: 1
# involvement: 1
# transition: 1
# invaded: 1
# border: 1
# raids: 1
# conquered: 1
# lasted: 1
# brief: 1
# interruption: 1
# occupied: 1
# 1945: 2
# puppet: 1
# successfully: 1
# nominated: 1
# unesco: 1
# reserve: 1
# kilograms: 1
# ounces: 1
# cyclos: 1
# cyclist: 1
# sits: 1
# behind: 1
# chacha: 1
# bolero: 1
# madison: 1
# turn: 1
# divided: 2
# communes: 1
# quarters: 2
# replacing: 1
# mao: 1
# zedong: 1
# 1956: 1
# 1955: 1
# abdicated: 1
# favour: 1
# participate: 1
# politics: 1
# elected: 1
# descended: 2
# neolithic: 1
# migrations: 1
# austronesian: 2
# insular: 1
# maintain: 1
# separate: 1
# villages: 1
# roads: 1
# paved: 1
# attack: 1
# overseas: 1
# club: 1
# rick: 1
# valenzuela: 1
# captured: 1
# video: 1
# plans: 2
# healthcare: 1
# raising: 1
# awareness: 1
# hivaids: 1
# malaria: 1
# diseases: 1
# kantrum: 1
# surin: 1
# instrumentation: 1
# champa: 1
# coast: 1
# presentday: 1
# rival: 1
# spoken: 1
# instruction: 1
# schools: 1
# december: 1
# succeed: 1
# next: 1
# kaplan: 1
# eyeglasses: 1
# deadly: 1
# yellow: 1
# star: 1
# seen: 2
# intellectualism: 1
# conducted: 1
# conflicts: 1
# lead: 1
# 36yearlong: 1
# gap: 1
# 61: 1
# inflation: 1
# interviews: 1
# interviewees: 1
# prostitute: 1
# norm: 1
# felt: 1
# shameful: 1
# having: 1
# lemon: 2
# kdau: 1
# kroch: 1
# chhma: 1
# reddust: 1
# juice: 1
# refreshing: 1
# hot: 1
# iced: 1
# served: 1
# hefty: 1
# dose: 1
# remnant: 1
# colonial: 1
# dialect: 1
# hydroelectric: 1
# pose: 1
# real: 1
# danger: 1
# subdivided: 1
# 159: 1
# cnrp: 1
# endorsed: 1
# speaker: 1
# members: 1
# favouritism: 1
# amid: 1
# tensions: 1
# boycotted: 1
# opening: 1
# curry: 1
# eaten: 1
# vermicelli: 1
# noodles: 2
# remote: 1
# uninhabited: 1
# peak: 1
# rises: 1
# elevation: 1
# 5949: 1
# visit: 1
# pagodas: 1
# mark: 1
# inland: 1
# waterways: 1
# elements: 1
# veneration: 1
# heroes: 1
# confucianism: 1
# taoism: 1
# mix: 1
# rooms: 1
# museum: 1
# photos: 1
# taken: 1
# given: 1
# mandate: 1
# enforce: 1
# ceasefire: 1
# refugees: 1
# disarmament: 1
# transitional: 2
# authority: 1
# indianized: 1
# cousins: 1
# consequently: 1
# culturally: 1
# distant: 1
# observing: 1
# preindiancontact: 1
# customs: 1
# beliefs: 1
# end: 1
# begins: 2
# sink: 1
# normal: 1
# allowing: 1
# reverse: 1
# attends: 1
# play: 1
# give: 1
# thanks: 1
# moon: 1
# fireworks: 1
# attend: 1
# race: 1
# carnivaltype: 1
# atmosphere: 1
# controversy: 1
# conservation: 1
# list: 1
# macaques: 1
# pros: 1
# founded: 1
# containing: 1
# 180: 1
# tree: 1
# riparian: 1
# ecosystems: 1
# beholden: 1
# occupying: 1
# direction: 1
# ambassador: 1
# households: 1
# depend: 1
# related: 1
# subsectors: 1
# communists: 1
# fighting: 1
# plains: 1
# gradually: 1
# merge: 1
# forested: 1
# plateaus: 1
# extend: 1
# rules: 1
# objections: 1
# thwart: 1
# diplomatically: 1
# useful: 1
# counterweight: 1
# closer: 1
# amnesty: 1
# prisoner: 1
# conscience: 1
# 33yearold: 1
# activist: 1
# yorm: 1
# bopha: 1
# scholar: 1
# george: 1
# coedes: 1
# refers: 1
# 10thcentury: 1
# inscription: 1
# dynastic: 1
# legend: 1
# hermit: 1
# swayambhuva: 1
# celestial: 1
# nymph: 1
# mera: 1
# unite: 1
# establish: 1
# dynasty: 1
# srutavarman: 1
# sreshthavarman: 1
# encompasses: 1
# vihear: 1
# judges: 1
# actually: 1
# survived: 1
# remained: 1
# shuttle: 1
# traffic: 2
# accident: 1
# standards: 1
# affects: 1
# judiciary: 1
# ended: 1
# crackdown: 1
# less: 1
# 3220: 1
# km2: 1
# future: 1
# sustainability: 1
# reserves: 1
# threat: 1
# regularly: 1
# ignoring: 1
# suppressing: 1
# encounter: 1
# everyday: 1
# lives: 1
# medical: 1
# dealing: 1
# alleged: 1
# violations: 1
# pursuing: 1
# verdicts: 1
# involves: 1
# local: 1
# businesses: 1
# authorities: 1
# transnational: 1
# corporations: 1
# exceeds: 1
# soups: 1
# time: 1
# remember: 1
# died: 1
# 19751979: 1
# master: 1
# 20142020: 1
# air: 1
# strikes: 1
# criminal: 1
# must: 1
# immediately: 1
# definitively: 1
# stop: 1
# represents: 1
# manufacturing: 1
# principal: 1
# crop: 1
# rubber: 1
# credentials: 1
# recognised: 1
# 25: 1
# legislative: 1
# powers: 1
# bicameral: 1
# consists: 1
# house: 2
# mainstay: 1
# spending: 1
# close: 1
# interrelationship: 1
# community: 1
# efficacy: 1
# apotropaic: 1
# luckattracting: 1
# charms: 1
# possibility: 1
# manipulating: 1
# contact: 1
# spiritual: 1
# baromey: 1
# originates: 1
# 212: 1
# mammal: 1
# 536: 1
# bird: 1
# 240: 1
# reptile: 1
# 435: 1
# marine: 1
# reintroduced: 1
# 750: 1
# seed: 1
# constitutional: 1
# parliamentary: 1
# democracy: 1

# %%
from collections import defaultdict

def build_ngram_model(data, n):
    model = defaultdict(lambda: defaultdict(int))
    for sentence in data:
        for i in range(len(sentence) - n + 1):
            ngram = tuple(sentence[i:i+n])
            prefix, token = ngram[:-1], ngram[-1]
            model[prefix][token] += 1
    return model

def backoff_prob(model, ngram):
    prefix, token = ngram[:-1], ngram[-1]
    if prefix in model and sum(model[prefix].values()) > 0:
        if token in model[prefix]:
            return model[prefix][token] / sum(model[prefix].values())
    elif len(prefix) > 1:
        return backoff_prob(model, prefix[1:] + (token,))
    return 0  # Default probability if no valid prefix or tokens


lm1 = build_ngram_model(train_tokens, 4)

# %%
# Build the LM2 interpolated method 
def interpolated_prob(model, ngram, lambdas, k):
    n = len(ngram)
    prob = 0
    for i in range(1, n+1):
        prefix, token = ngram[:i-1], ngram[i-1]
        count = model[prefix][token] + k
        total_count = sum(model[prefix].values()) + k * vocab_size
        prob += lambdas[i-1] * (count / total_count)
    return prob

lambdas = [0.1, 0.2, 0.3, 0.4]  # Example weights
k = 1  # Example smoothing parameter

# %%
import math
def perplexity(model, tokens, prob_func):
    log_prob = 0
    word_count = 0
    for sentence in tokens:
        for i in range(3, len(sentence)):
            ngram = tuple(sentence[i-3:i+1])
            prob = prob_func(model, ngram)
            # Ensure probability is a small positive value
            if prob <= 0:
                prob = 1e-10  # Assign a small positive probability
            log_prob += math.log2(prob)
            word_count += 1
    return 2 ** (-log_prob / word_count)


pp_lm1 = perplexity(lm1, test_tokens, backoff_prob)
pp_lm2 = perplexity(lm1, test_tokens, lambda m, n: interpolated_prob(m, n, lambdas, k))

print(f"pp_lm1: {pp_lm1}")
print(f"pp_lm2: {pp_lm2}")
# Out:
# pp_lm1: 6482841614.53346
# pp_lm2: 19786.35481142604

# %%
def generate_text(model, start, length, prob_func):
    text = list(start)
    for _ in range(length - len(start)):
        prefix = tuple(text[-3:])
        if prefix not in model or not model[prefix] or sum(model[prefix].values()) == 0:
            print(f"Prefix not found or has zero probability: {prefix}. Stopping generation.")
            break  # Stop generation if prefix is invalid
        else:
            next_word = max(model[prefix], key=lambda x: prob_func(model, prefix + (x,)))
            text.append(next_word)
    return ' '.join(text)
# Ensure start tokens match the model's keys
start = list(random.choice(list(lm1.keys())))
print('LM1:', generate_text(lm1, start, 50, backoff_prob))
# Out:
# Prefix not found or has zero probability: ('in', 'the', '1970s'). Stopping generation.
# LM1: established diplomatic relations with numerous countries the government reports twenty embassies in the country s terror period in the 1970s
